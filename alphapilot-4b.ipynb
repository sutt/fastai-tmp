# %% [markdown]
# ### Looking at the outcome/predictions of different models
# models mostly built 4/8-4/10

# %%
import os, sys, json, copy, random
import pandas as pd
import numpy as np
from fastai.vision import *
from fastai.utils.mem import  gpu_mem_get_free_no_cache
from modules.ap3data import build_data
gpu_mem_get_free_no_cache()
# Out:
# 0

# %%
# %reload_ext autoreload
# %autoreload 2
from modules.ap3graph import *

# %%
'''
TODO
[ ] compare different models
[ ] sort by loss: worst, best
[ ] 
'''

# %% [markdown]
# ##### Load the model you want

# %%
# use this to copy from old-models to learner-path expecting .pth
# !cp old-models/ap4-resnet54-1.pth ../../../../alphapilot/Data_Training/Data_Training/models/ap4-resnet50-1.pth

# %%
#big1 : 0.011 valid err model
data_size288_bs8 = build_data(size=(288, 432), batch_size=8)
learn_both = cnn_learner(data_size288_bs8, models.resnet34)
_ = learn_both.load('ap4-big-1')

# %%
#big-2 : 0.005 valid err model

# %%
#resnet50 - 0.0033 valid-err model
data_size288_bs32 = build_data(size=(288, 432), batch_size=32)
learn_50 = cnn_learner(data_size288_bs32, models.resnet50)
_ = learn_50.load('ap4-resnet50-1')

# %% [markdown]
# ##### Manual Calc Err Metric

# %%
# build average
data = build_data()

# %%
# preds5 = learn_both.get_preds(n_batch=5, with_loss=True)
# len(preds5[0])
# len([float(e) for e in list(preds5[2])])
# sum(preds5[2]) / 320

# %% [markdown]
# ##### View prediction plots

# %%
i=0
pred_compare(data_size288_bs32, learn_50, size=(288, 432), i=i)

# %%
i=495
pred_compare(data_size288_bs32, learn_50, size=(288, 432), i=i)

# %%
for _ in range(10):
    pred_compare(data_size288_bs32, 
                 learn_50, 
                 size=(288, 432), 
                 i=None, 
                 b_print=True)
# Out:
# 948 IMG_6809.JPG
# 929 IMG_0149.JPG
# 912 IMG_1231.JPG
# 643 IMG_3604.JPG
# 426 IMG_4165.JPG
# 501 IMG_2692.JPG
# 729 IMG_5314.JPG
# 70 IMG_9915.JPG
# 477 IMG_8398.JPG
# 456 IMG_7908.JPG
